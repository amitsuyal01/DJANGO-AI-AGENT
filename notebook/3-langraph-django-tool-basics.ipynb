# %%
from setup import init
init()

# %%
from ai.tools import list_documents, get_document_by_id

# %%
config = {
    "user_id": 1
}

# %%
list_documents.invoke(None, config)
# Out:
# [{'id': 2, 'name': 'title'}, {'id': 1, 'name': 'title'}]

# %%
get_document_by_id.invoke({"document_id": 1}, config)
# Out:
# user_id:  1
# {'id': 1, 'name': 'title'}
