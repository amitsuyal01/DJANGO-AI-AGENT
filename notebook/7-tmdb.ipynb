# %%
from setup import init
init()

# %%
from tmdb.client import search_movies, movie_details

# %%
result = search_movies("Matrix")
id = result.get('results')[0].get("id")

# %%
movie_name = movie_details(id).get('title')

# %%
print(movie_name)
# Out:
# The Matrix
